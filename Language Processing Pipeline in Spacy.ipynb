# %%
import spacy

# %%
nlp = spacy.blank("en")

doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
  print(token)
# Out:
# Captain
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f3b595d2e00>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f3b595d1fc0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f3b598b5f50>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f3b5938d000>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f3b5946d9c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f3b598b6260>)]

# %%
doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
  print(token, " | ", token.pos_, " | ", token.lemma_)
# Out:
# Captain  |  PROPN  |  Captain
# america  |  PROPN  |  america
# ate  |  VERB  |  eat
# 100  |  NUM  |  100
# $  |  NUM  |  $
# of  |  ADP  |  of
# samosa  |  PROPN  |  samosa
# .  |  PUNCT  |  .
# Then  |  ADV  |  then
# he  |  PRON  |  he
# said  |  VERB  |  say
# I  |  PRON  |  I
# can  |  AUX  |  can
# do  |  VERB  |  do
# this  |  PRON  |  this
# all  |  DET  |  all
# day  |  NOUN  |  day
# .  |  PUNCT  |  .

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion money")

for ent in doc.ents:
  print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy

displacy.render(doc, style="ent", jupyter=True, options={'distance': 90})
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">\n<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Tesla Inc\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>\n</mark>\n is going to acquire twitter for \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    $45 billion\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>\n</mark>\n money</div>'

# %%
nlp = spacy.blank("en")

doc = nlp("Tesla Inc is going to acquire twitter for $45 billion money")

for ent in doc.ents:
  print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))

# %%
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank('en')

nlp.add_pipe('ner', source=source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion money")

for ent in doc.ents:
  print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deplacy
#   Downloading deplacy-2.0.5-py3-none-any.whl (22 kB)
# Installing collected packages: deplacy
# Successfully installed deplacy-2.0.5

# %%
import spacy
import deplacy

nlp=spacy.load('en_core_web_sm')
doc=nlp('I saw a horse yesterday which had no name.')
deplacy.render(doc)
# Out:
# I         PRON  <══════════════╗   nsubj
# saw       VERB  ═══════════╗═╗═╝═╗ ROOT
# a         DET   <════════╗ ║ ║   ║ det
# horse     NOUN  ═══════╗═╝<╝ ║   ║ dobj
# yesterday NOUN  <══════║═════╝   ║ npadvmod
# which     PRON  <════╗ ║         ║ nsubj
# had       VERB  ═══╗═╝<╝         ║ relcl
# no        DET   <╗ ║             ║ det
# name      NOUN  ═╝<╝             ║ dobj
# .         PUNCT <════════════════╝ punct
